# %%
print("Teste")
# Out:
# Teste

# %%
import calc as cl

# %%
print("")



op = int( input('''Digite qual o número correspondente à operação que deseja realizar:
                1 - Soma
                2 - Subtração
                3 - Multiplicação
                4 - Divisão
                5 - Potenciação
                6 - Raiz''') )

if op == 6:
    b = float(input("Digite o índice da raiz: "))
    a = float(input("Digite o número: "))
    print(f"O resultado da raiz é: {cl.raiz(a, b)}")

else:
    a = float(input("Digite o primeiro número: "))
    b = float(input("Digite o segundo número: "))

    if op == 1:
        print("Resultado:", cl.soma(a, b))
    elif op == 2:
        print("Resultado:", cl.subtracao(a, b))
    elif op == 3:
        print("Resultado:", cl.multiplicacao(a, b))
    elif op == 4:
        print("Resultado:", cl.divisao(a, b))
    elif op == 5:
        print("Resultado:", cl.potencia(a, b))
# Out:
# O resultado da raiz é: 2.0
